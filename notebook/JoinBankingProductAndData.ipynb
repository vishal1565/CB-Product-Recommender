# %%
from tensorflow import keras

import pandas as pd
from pandas import Series, DataFrame
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier

from keras.utils import np_utils

# %%
banking_product=pd.read_csv('prod_outp.csv')
banking_product.head()
# Out:
#         Country  bills of exchange       cash  certificates  commitments  \
# 0        brazil           0.000000   0.000000      0.000000     0.000000
# 1         china        1310.663882   0.000000      0.000000     0.000000
# 2       germany          56.807110   0.789649    329.986926    62.284541
# 3         india           0.000000  14.156424      0.000000     0.000000
# 4  saudi arabia          11.613966   0.000000      0.000000     0.000000
#
#    debt securities  derivatives  equities securities  finance lease  \
# 0         0.000000     0.000000             0.000000        0.00000
# 1         0.000000     0.000000             0.000000        0.00000
# 2      3544.428800  1561.215334          4332.705804        1.91479
# 3         0.000000     0.000000             0.000000        0.00000
# 4         2.374158     0.000000             0.000000        0.00000
#
#    financial guarantees  fx derivaties  interest rate derivatives  \
# 0            273.939019        0.00000                   0.000000
# 1           1150.178624        0.00000                   0.000000
# 2          47221.623840    69276.90385                1091.125039
# 3              0.000000        0.00000                   0.000000
# 4            451.276940        0.00000                   0.000000
#
#    lending and borrowing  letter of credits         loans  \
# 0                0.00000           2.157821  1.479564e+02
# 1                0.00000          26.390057  2.427064e+02
# 2               63.97222         901.383508  4.071584e+06
# 3                0.00000           0.000000  1.002188e+05
# 4                0.00000          48.564001  1.110493e+01
#
#    performance guarantees      repo  trade financing  Year
# 0              223.307791  0.000000      26589.93331  2012
# 1             3538.104673  0.000000      10944.64428  2012
# 2            50736.560830  0.000000     127387.01740  2012
# 3                0.000000  0.000000          0.00000  2012
# 4              753.702104  1.035444         12.79539  2012

# %%
data=pd.read_csv('complete_dataset_with_indices1.csv', encoding = 'UTF-8')
data.head()
# with open('complete_dataset_with_indices.csv') as f:
    # print(f)
# Out:
#    Year TargetCountry SourceCountry  ImportValue  Product  weatherIndex  \
# 0  2012        Brazil         China          0.0  data\38          0.07
# 1  2013        Brazil         China     328924.0  data\38          0.03
# 2  2014        Brazil         China     377498.0  data\38          0.21
# 3  2015        Brazil         China     269437.0  data\38          0.01
# 4  2016        Brazil         China     331536.0  data\38          0.01
#
#    geoPoliticalIndex
# 0               0.03
# 1               0.03
# 2               0.04
# 3               0.04
# 4               0.04
